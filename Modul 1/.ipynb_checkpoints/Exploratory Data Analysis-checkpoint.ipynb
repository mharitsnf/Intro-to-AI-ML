# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# In statistics, exploratory data analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often with visual methods. A statistical model can be used or not, but primarily EDA is for seeing what the data can tell us beyond the formal modeling or hypothesis testing task.

# %% [markdown]
# Pertama-tama mari kita import library yang akan kita gunakan. Kali ini, kita akan menggunakan library Pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Mari buka file CSV yang akan di eksplor. Kali ini, kita akan mengeksplor dataset Pokemon.

# %%
df = pd.read_csv('dataset/Pokemon.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.drop('#', axis = 1, inplace = True)
df.drop('Generation', axis = 1, inplace = True)
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Legendary
# 0       65     45      False
# 1       80     60      False
# 2      100     80      False
# 3      120     80      False
# 4       50     65      False

# %%
df.loc[:,'Name'] = df.loc[:,'Name'].str.replace(r'\w*Mega', 'Mega', regex = True)
df.head()
# Out:
#             Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1        Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2       Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  Mega Venusaur  Grass  Poison    625  80     100      123      122      120
# 4     Charmander   Fire     NaN    309  39      52       43       60       50
#
#    Speed  Legendary
# 0     45      False
# 1     60      False
# 2     80      False
# 3     80      False
# 4     65      False

# %%
df.shape
# Out:
# (800, 11)

# %%
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed
# count  800.000000
# mean    68.277500
# std     29.060474
# min      5.000000
# 25%     45.000000
# 50%     65.000000
# 75%     90.000000
# max    180.000000

# %%
df.Legendary.value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_44f2a27e_c330_11e9_9866_c4e9840921f5row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row0_col1 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row0_col2 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row0_col3 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row0_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row0_col5 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row0_col6 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row0_col7 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row1_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row1_col2 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row1_col3 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row1_col4 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row1_col5 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row1_col6 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row1_col7 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row2_col0 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row2_col1 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row2_col3 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row2_col4 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row2_col5 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row2_col6 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row2_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row3_col0 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row3_col1 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row3_col2 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row3_col5 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row3_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row3_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row4_col0 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row4_col1 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row4_col2 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row4_col3 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row4_col5 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row4_col6 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row4_col7 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row5_col0 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row5_col1 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row5_col3 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row5_col4 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row5_col6 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row5_col7 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row6_col0 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row6_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row6_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row6_col4 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row6_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row6_col7 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row7_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row7_col1 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row7_col2 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_44f2a27e_c330_11e9_9866_c4e9840921f5row7_col3 {
#             background-color:  #88abfd;
#             color:  #000000;

# %%
df['Total']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-3b12c41b371c> in <module>
# ----> 1 df[:,1]
#
# ~/Documents/Personal/Intro-to-AI-ML/venv/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2973             if self.columns.nlevels > 1:
#    2974                 return self._getitem_multilevel(key)
# -> 2975             indexer = self.columns.get_loc(key)
#    2976             if is_integer(indexer):
#    2977                 indexer = [indexer]
#
# ~/Documents/Personal/Intro-to-AI-ML/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888                 )
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#    2892                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 1)' is an invalid key
